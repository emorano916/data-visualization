# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# set this so the 
# %matplotlib inline

# %%
amazon = pd.read_csv('amazon_co-ecommerce_sample.csv')
amazon.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
#
#                                         product_name manufacturer   price  \
# 0                              Hornby 2014 Catalogue       Hornby   £3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  £16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   £9.99
# 3     HORNBY Coach R4410A BR Hawksworth Corridor 3rd       Hornby  £39.99
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby  £32.19
#
#   number_available_in_stock number_of_reviews  number_of_answered_questions  \
# 0                     5 new                15                           1.0
# 1                       NaN                 2                           1.0
# ...

# %%
amazon_group = amazon.groupby('manufacturer')['number_of_reviews'].value_counts().head()

# %%
#amazon['price'] = amazon['price'].replace({'\£': ''}, regex=True).astype(float)
amazon['price'] = amazon['price'].str.replace('£','').str.replace.astype('float')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-3227024c7498> in <module>
#       1 #amazon['price'] = amazon['price'].replace({'\£': ''}, regex=True).astype(float)
# ----> 2 amazon['price'] = amazon['price'].str.replace('£','').str.replace.astype('float')
#
# AttributeError: 'function' object has no attribute 'astype'

# %%
# get the Series of the names
amazon_group.dropna()
x = amazon_group.manufacturer

y = amazon_gourp.number_of_reviews

# use the Counter class from collections to create a dictionary with keys(text) and frequency
#letter_counts = Counter(x)

# convert the dictionary to a DataFrame
#df = pd.DataFrame.from_dict(letter_counts, orient='index')

# sort the values from the top to the least value and slice the first 5 items
#df = df[0].sort_values(ascending = True)

# create the plot
amazon_group.plot(x,y,kind='bar')

# Set the title and labels
plt.xlabel('Manufacturer')
plt.ylabel('Price')
plt.title('Supplier middle price')

# show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-845a1b37ad94> in <module>
#       1 # get the Series of the names
#       2 amazon_group.dropna()
# ----> 3 x = amazon_group.manufacturer
#       4
#       5 y = amazon_gourp.number_of_reviews
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'manufacturer'

# %%
# get the Series of the names
x = amazon.manufacturer

z = amazon.number_of_reviews

# use the Counter class from collections to create a dictionary with keys(text) and frequency
#letter_counts = Counter(x)

# convert the dictionary to a DataFrame
#df = pd.DataFrame.from_dict(letter_counts, orient='index')

# sort the values from the top to the least value and slice the first 5 items
#df = df[0].sort_values(ascending = True)

# create the plot
amazon.plot(x,z)

# Set the title and labels
plt.xlabel('Manufacturer')
plt.ylabel('Price')
plt.title('Supplier middle price')

# show the plot
plt.show()

# %%
# get the Series of the names
x = amazon.product_name

# use the Counter class from collections to create a dictionary with keys(text) and frequency
letter_counts = Counter(x)

# convert the dictionary to a DataFrame
amazon = pd.DataFrame.from_dict(letter_counts, orient='index')

# sort the values from the top to the least value and slice the first 5 items
amazon = amazon[0].sort_values(ascending = True)[45:50]

# create the plot
amazon.plot(kind='bar')

# Set the title and labels
plt.xlabel('Product mame')
plt.ylabel('Price')
plt.title('Most ordered product')

# show the plot
plt.show()

# %%
# create a list of prices
amazon.price = [float(value[1:-1]) for value in amazon.price] # strip the dollar sign and trailing space

# then groupby the orders and sum
orders = amazon.groupby('number_of_reviews').sum()

# creates the scatterplot
# plt.scatter(orders.quantity, orders.item_price, s = 50, c = 'green')
plt.scatter(x = orders.price, y = orders.number_of_reviews, s = 50, c = 'green')

# Set the title and labels
plt.xlabel('Order Price')
plt.ylabel('Items ordered')
plt.title('Number of items ordered per order price')
plt.ylim(0)

# %%
amazon = pd.read_csv('amazon_co-ecommerce_sample.csv')
amazon.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-f10706317b89> in <module>
#       1 amazon.dropna()
# ----> 2 plt.scatter(amazon.number_of_reviews, amazon.number_available_in_stock)
#       3
#       4 #set labels and titles
#       5 plt.title("preTestScore x postTestScore")
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2809         verts=cbook.deprecation._deprecated_parameter,
#    2810         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2811     __ret = gca().scatter(
#    2812         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2813         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ...

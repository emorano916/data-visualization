# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv
from collections import Counter
from operator import itemgetter

# set this so the 
# %matplotlib inline

# %%
amazon = pd.read_csv('amazon_co-ecommerce_sample.csv')
amazon.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
#
#                                         product_name manufacturer   price  \
# 0                              Hornby 2014 Catalogue       Hornby   £3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  £16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   £9.99
# 3     HORNBY Coach R4410A BR Hawksworth Corridor 3rd       Hornby  £39.99
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby  £32.19
#
#   number_available_in_stock number_of_reviews  number_of_answered_questions  \
# 0                     5 new                15                           1.0
# 1                       NaN                 2                           1.0
# ...

# %%
plt.style.use('fivethirtyeight')
with open('amazon_co-ecommerce_sample.csv', 'r', encoding='utf8') as csv_file:
    csv_reader= csv.reader(csv_file)
    next(csv_reader)
    list_of_manufacturers = []
    for line in csv_reader:
        list_of_manufacturers.append(line[2])
    counting_manu = Counter(list_of_manufacturers).most_common(5)

names_of_manufacturers = []
most_products = []
for i in counting_manu:
    names_of_manufacturers.append(i[0])
    most_products.append(i[1])

plt.bar(names_of_manufacturers, most_products, width = 0.6
       )
plt.ylabel('number of products')
plt.xlabel('manufacturers')
plt.xticks(rotation=30)
plt.title ('Top 5 manufacturers by presence on Amazon')

plt.show()

# %%
plt.style.use('fivethirtyeight')
with open('amazon_co-ecommerce_sample.csv', 'r', encoding='utf8') as csv_file:
    csv_reader = csv.reader(csv_file)
    next(csv_reader)
    amazon_category_and_sub_category = []
    for items in csv_reader:
        amazon_category_and_sub_category.append(items[8].split('>'))

category = []
counter = 0
while counter < len(amazon_category_and_sub_category):
    for z in amazon_category_and_sub_category:
        category.append(amazon_category_and_sub_category[counter][-1])
        counter+=1
Couting_each = Counter(category).most_common(5)
numb = []
catg = []
for f in Couting_each:
    numb.append(f[1])
    catg.append(f[0])
plt.bar(catg, numb)
plt.xlabel('Popular Categories')
plt.ylabel('Numbers of products')
plt.xticks(rotation=70)
plt.title('Top 5 categories on Amazon')
plt.show()

# %%
#extract average review rating and transform to float
amazon['average_review_rating'] = amazon['average_review_rating'].str.extract(r'(^.{3})')
amazon['average_review_rating'] = amazon['average_review_rating'].astype(float)

#extract number of reviews rating and transform to float
amazon['number_of_reviews'] = amazon['number_of_reviews'].str.replace(',','.')
amazon['number_of_reviews'] = amazon['number_of_reviews'].astype(float)

#extract price of reviews rating and transform to float
amazon['price'] = amazon['price'].str.replace(',','.').str.extract(r'(\d+.{4})')
amazon['price'] = amazon['price'].astype(float)

# %%
#sorting price under 200£
amazon_light = amazon[amazon['price']<200]

# %%
#start scatter plot
amazon_light.plot.scatter('number_of_reviews','average_review_rating', s=70,
                          alpha = .9, c='price', colormap='plasma', label = "Toys sold and rated on Amazon", figsize=(15,7))

#add labels and title
plt.xlabel('Number of reviews', labelpad=15)
plt.ylabel('Average rating', labelpad=15)
plt.title('Average rating according to number of reviews & price < 200£' ,pad=20)
# Out:
# Text(0.5, 1.0, 'Average rating according to number of reviews & price < 200£')

# %%
#sorting price under 200£
amazon_light2 = amazon[amazon['price']<50]

#start scatter plot
amazon_light2.plot.scatter('number_of_reviews','average_review_rating', s=70,
                          alpha = .8, c='price', colormap='Paired', label = "Toys sold and rated on Amazon", figsize=(15,7))

#add labels and title
plt.xlabel('Number of reviews', labelpad=15)
plt.ylabel('Average rating',labelpad=15)
plt.title('Average rating according to number of reviews & price < 50£', pad=30)
# Out:
# Text(0.5, 1.0, 'Average rating according to number of reviews & price < 50£')
